# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Market.csv") # reading the dataset
data
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %% [markdown]
# **Here I tried to remove decimals in "Adj close" column, and got error. I need to recognize and remove missing values at firt**
#
# df1["Adj Close"] = df1["Adj Close"].astype(int)
# df1

# %%
df= pd.DataFrame (data)
df
# Out:
#        Index        Date         Open         High          Low        Close  \
# 0        NYA  12/31/1965   528.690002   528.690002   528.690002   528.690002
# 1        NYA    1/3/1966   527.210022   527.210022   527.210022   527.210022
# 2        NYA    1/4/1966   527.840027   527.840027   527.840027   527.840027
# 3        NYA    1/5/1966   531.119995   531.119995   531.119995   531.119995
# 4        NYA    1/6/1966   532.070007   532.070007   532.070007   532.070007
# ...      ...         ...          ...          ...          ...          ...
# 112452  N100   5/27/2021  1241.119995  1251.910034  1241.119995  1247.069946
# 112453  N100   5/28/2021  1249.469971  1259.209961  1249.030029  1256.599976
# 112454  N100   5/31/2021  1256.079956  1258.880005  1248.140015  1248.930054
# 112455  N100    6/1/2021  1254.609985  1265.660034  1254.609985  1258.579956
# 112456  N100    6/2/2021  1258.489990  1263.709961  1258.239990  1263.619995
#
#           Adj Close       Volume
# ...

# %%
df_NYA = df[df['Index'] == 'NYA']      # making a new Data Frame for NYA indeces 
df_NYA
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %% [markdown]
# # Figuring out duplicated rows

# %%
df_NYA[df_NYA.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Index, Date, Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %% [markdown]
# **No data is duplicated** *so we can continue*

# %%
df_NYA.describe()       # describing the data to recognize missing values and noises
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13947.000000  13946.000000  13945.000000  13944.000000  13938.000000
# mean    4452.147406   4469.312526   4434.262223   4453.026486   4455.094446
# std     4074.835507   4094.956718   4052.815490   4075.483921   4075.456765
# min      347.769989    347.769989    347.769989    347.769989    347.769989
# 25%      654.989990    655.150024    655.039978    655.122513    655.807525
# 50%     2631.909912   2632.280029   2631.909912   2632.015014   2633.015014
# 75%     7339.489990   7376.315063   7277.509766   7339.397583   7342.787598
# max    16590.429690  16685.890630  16531.949220  16590.429690  16590.429690
#
#              Volume
# count  1.394700e+04
# mean   1.215565e+09
# std    1.834155e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.681975e+09
# max    1.145623e+10

# %% [markdown]
# # ploting features vs. target scatterplots to recognize noises and their ranges

# %%
plt.figure(figsize=(15,6))
plt.title("Open price vs. Adj Close price for NYA")
plt.scatter(df_NYA['Open'],df_NYA['Adj Close'],alpha=0.4)
plt.xlabel("Opening price")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# <span style="color:red;font-weight:bold;font-size:12pt;font-style:italic"> There are two(2) noises which should be extracted

# %%
plt.figure(figsize=(15,6))
plt.title("Maximum price vs. Adj Close price for NYA")
plt.scatter(df_NYA['High'],df_NYA['Adj Close'],alpha=0.4)
plt.xlabel("Maximum price")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# <span style="color:red;font-weight:bold;font-size:12pt;font-style:italic"> There are three(3) noises which should be extracted

# %%
plt.figure(figsize=(15,6))
plt.title("Minimum price vs. Adj Close price for NYA")
plt.scatter(df_NYA['Low'],df_NYA['Adj Close'],alpha=0.4)
plt.xlabel("Minimum price")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# <span style="color:red;font-weight:bold;font-size:12pt;font-style:italic"> There are one(1) noise which should be extracted

# %%
plt.figure(figsize=(15,6))
plt.title("Closing price vs. Adj Close price for NYA")
plt.scatter(df_NYA['Close'],df_NYA['Adj Close'],alpha=0.4)
plt.xlabel("Closing price")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# <span style="color:red;font-weight:bold;font-size:12pt;font-style:italic"> There are one(1) noise which should be extracted

# %%
plt.figure(figsize=(15,6))
plt.title("volume vs. Adj Close price for NYA")
plt.scatter(df_NYA['Volume'],df_NYA['Adj Close'],alpha=0.4)
plt.xlabel("volume")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# # Extracting the noises out of dataset

# %%
df1 = df_NYA[((5500 < df_NYA["Open"]) & (df_NYA["Open"] < 6000) & (0 < df_NYA["Adj Close"]) & (df_NYA["Adj Close"] < 2000)) |
             ((0 < df_NYA["Open"]) & (df_NYA["Open"] < 1000) & (5800 < df_NYA["Adj Close"]) & (df_NYA["Adj Close"] < 6500))]
df1          # df1 refers to a dataframe showing the indices of noises
# Out:
#     Index       Date         Open        High         Low       Close  \
# 831   NYA  5/29/1969   611.900024  611.900024  611.900024  611.900024
# 852   NYA  6/30/1969  5722.359985  572.359985  572.359985  572.359985
#
#        Adj Close  Volume
# 831  6110.900024     0.0
# 852   572.359985     0.0

# %%
df_NYA_1 = df_NYA.drop(df1.index)    # extracting the noises of the first plot by having their indeces 
df_NYA_1
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close     Adj Close        Volume
# 0        528.690002    528.690002  0.000000e+00
# 1        527.210022    527.210022  0.000000e+00
# ...

# %%
# plotting again to check whether it was correct 

plt.figure(figsize=(15,6))
plt.title("Open price vs. Adj Close price for NYA")
plt.scatter(df_NYA_1['Open'],df_NYA_1['Adj Close'],alpha=0.4)
plt.xlabel("Opening price")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:12pt;font-style:italic;">&#10004; Two(2) noises are successfully removed</span>

# %%
df2 = df_NYA[((5800 < df_NYA["High"]) & (df_NYA["High"] < 6500) & (0 < df_NYA["Adj Close"]) & (df_NYA["Adj Close"] < 2000)) |
             ((0 < df_NYA["High"]) & (df_NYA["High"] < 2000) & (5800 < df_NYA["Adj Close"]) & (df_NYA["Adj Close"] < 6500))]
df2          # df2 refers to a dataframe showing the indices of noises
# Out:
#     Index       Date        Open         High         Low       Close  \
# 829   NYA  5/27/1969  612.219971  6124.219971  612.219971  612.219971
# 831   NYA  5/29/1969  611.900024   611.900024  611.900024  611.900024
# 833   NYA   6/3/1969  606.830017  6065.830017  606.830017  606.830017
#
#        Adj Close  Volume
# 829   612.219971     0.0
# 831  6110.900024     0.0
# 833   606.830017     0.0

# %% [markdown]
# <span style="color:blue;font-weight:bold;font-size:12pt;font-style:italic;"> those three(3) noises are recognized

# %%
df_NYA_2 = df_NYA.drop(df2.index)    # extracting the noises of the second plot by having their indeces

# %%
plt.figure(figsize=(15,6))
plt.title("Maximum price vs. Adj Close price for NYA")
plt.scatter(df_NYA_2['High'],df_NYA_2['Adj Close'],alpha=0.4)
plt.xlabel("Maximum price")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:12pt;font-style:italic;">&#10004; Three(3) noises are successfully removed</span>

# %%
df3 = df_NYA[((0 < df_NYA["Low"]) & (df_NYA["Low"] < 2000) & (5800 < df_NYA["Adj Close"]) & (df_NYA["Adj Close"] < 6500))]
df3          # df3 refers to a dataframe showing the indices of noises in Min price vs. Adj. close
# Out:
#     Index       Date        Open        High         Low       Close  \
# 831   NYA  5/29/1969  611.900024  611.900024  611.900024  611.900024
#
#        Adj Close  Volume
# 831  6110.900024     0.0

# %%
df_NYA_3 = df_NYA.drop(df3.index)    # extracting the noises of the Third plot by having their indeces

# %%
plt.figure(figsize=(15,6))
plt.title("Minimum price vs. Adj Close price for NYA")
plt.scatter(df_NYA_3['Low'],df_NYA_3['Adj Close'],alpha=0.4)
plt.xlabel("Minimum price")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:12pt;font-style:italic;">&#10004; One(1) noise is successfully removed</span>

# %%
df4 = df_NYA[((0 < df_NYA["Close"]) & (df_NYA["Close"] < 2000) & (5800 < df_NYA["Adj Close"]) & (df_NYA["Adj Close"] < 6500))]
df4          # df4 refers to a dataframe showing the indices of noises in Min price vs. Adj. close
# Out:
#     Index       Date        Open        High         Low       Close  \
# 831   NYA  5/29/1969  611.900024  611.900024  611.900024  611.900024
#
#        Adj Close  Volume
# 831  6110.900024     0.0

# %%
df_NYA_4 = df_NYA.drop(df4.index)    # extracting the noises of the forth plot by having their indeces

# %%
plt.figure(figsize=(15,6))
plt.title("Closing price vs. Adj Close price for NYA")
plt.scatter(df_NYA_4['Close'],df_NYA_4['Adj Close'],alpha=0.4)
plt.xlabel("Closing price")
plt.ylabel("Adj Close")
plt.grid()

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:12pt;font-style:italic;">&#10004; One(1) noise is successfully removed</span>

# %%
# Combine index labels from all DataFrames
combined_index = df1.index.union(df2.index).union(df3.index).union(df4.index)

# Drop rows from df_NYA based on the combined index
filtered_data = df_NYA.drop(combined_index)

combined_index
# Out:
# Index([829, 831, 833, 852], dtype='int64')

# %%
filtered_data.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13943.000000  13942.000000  13941.000000  13940.000000  13934.000000
# mean    4452.882920   4469.635502   4435.362126   4454.131852   4455.806235
# std     4075.016076   4095.234524   4052.876577   4075.546081   4075.624383
# min      347.769989    347.769989    347.769989    347.769989    347.769989
# 25%      655.150024    655.230011    655.469971    655.544998    656.017487
# 50%     2632.120117   2632.280029   2632.439941   2632.439941   2633.704956
# 75%     7342.455078   7377.210083   7278.419922   7342.082519   7345.524902
# max    16590.429690  16685.890630  16531.949220  16590.429690  16590.429690
#
#              Volume
# count  1.394300e+04
# mean   1.215914e+09
# std    1.834302e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.682940e+09
# max    1.145623e+10

# %% [markdown]
# # Missing values
# **It seems that there are some Nan rows which are negligible**
# *using "dropna" function to remove them from our data*

# %%
print ("show the missing values of the filtered dataframe: \n\n", filtered_data.isnull().sum() )
# Out:
# show the missing values of the filtered dataframe:
#
#  Index         0
# Date          0
# Open          1
# High          2
# Low           3
# Close         4
# Adj Close    10
# Volume        1
# dtype: int64

# %%
DF = filtered_data.dropna(axis=0)  # using dropna to remove Nan in arrows 
DF.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count  13928.000000  13928.000000  13928.000000  13928.000000  13928.000000
# mean    4457.122309   4473.603377   4439.014504   4457.519410   4457.519410
# std     4075.160214   4095.378126   4053.002787   4075.665989   4075.665989
# min      347.769989    347.769989    347.769989    347.769989    347.769989
# 25%      656.419983    656.419983    656.419983    656.419983    656.419983
# 50%     2634.179931   2634.179931   2634.179931   2634.179931   2634.179931
# 75%     7350.584961   7385.307617   7282.672363   7348.750122   7348.750122
# max    16590.429690  16685.890630  16531.949220  16590.429690  16590.429690
#
#              Volume
# count  1.392800e+04
# mean   1.217224e+09
# std    1.834855e+09
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    2.687250e+09
# max    1.145623e+10

# %% [markdown]
# <span style="color:green;font-weight:bold;font-size:12pt;font-style:italic;">&#10004; DF without noise and Nan

# %% [markdown]
# # Removing Decimals

# %% [markdown]
# **Decimals are removed in "Adj Close" column.**

# %%
DF.loc[:,'Adj Close'] = DF['Adj Close'].astype(int)
DF
# Out:
#       Index        Date          Open          High           Low  \
# 0       NYA  12/31/1965    528.690002    528.690002    528.690002
# 1       NYA    1/3/1966    527.210022    527.210022    527.210022
# 2       NYA    1/4/1966    527.840027    527.840027    527.840027
# 3       NYA    1/5/1966    531.119995    531.119995    531.119995
# 4       NYA    1/6/1966    532.070007    532.070007    532.070007
# ...     ...         ...           ...           ...           ...
# 13943   NYA   5/24/2021  16375.000000  16508.519530  16375.000000
# 13944   NYA   5/25/2021  16464.689450  16525.810550  16375.150390
# 13945   NYA   5/26/2021  16390.189450  16466.339840  16388.320310
# 13946   NYA   5/27/2021  16451.960940  16546.359380  16451.960940
# 13947   NYA   5/28/2021  16531.949220  16588.689450  16531.949220
#
#               Close  Adj Close        Volume
# 0        528.690002      528.0  0.000000e+00
# 1        527.210022      527.0  0.000000e+00
# ...

# %%
year=pd.to_datetime (DF.Date).dt.year
month=pd.to_datetime (DF.Date).dt.month
date=pd.to_datetime (DF.Date).dt.date
year
# Out:
# 0        1965
# 1        1966
# 2        1966
# 3        1966
# 4        1966
#          ...
# 13943    2021
# 13944    2021
# 13945    2021
# 13946    2021
# 13947    2021
# Name: Date, Length: 13928, dtype: int32

# %% [markdown]
# # Linear Analysis of Date vs. Adj Close Price

# %%
plt.figure(figsize=(15, 10), dpi=80)
plt.plot(DF["Date"], DF["Adj Close"])
plt.title("Linear analysis of Adj close vs. Date for NYA")
plt.xlabel("Date")
plt.ylabel("Adj Close")

# Set the tick frequency and rotation- REMEMBER that date is like str.
plt.xticks(DF["Date"][::len(DF["Date"]) // 50], rotation=90)

plt.show()

# %%
plt.figure(figsize=(15, 10), dpi=80)
plt.title ("Number of rows per year")
plt.xticks(rotation=90)
sns.countplot (x=year)
# Out:
# <Axes: title={'center': 'Number of rows per year'}, xlabel='Date', ylabel='count'>

# %% [markdown]
# **The last diagram illustrates that although we have increase in the Adj close price in 2021, but the number of datapoints for  year 2021 is less. Therefore the density of the datapoints has decreased for the last year. It is good to discuss this issue with the data owner and get more thoughts on that.**
